# %% [markdown]
# <a href="https://colab.research.google.com/github/bforoura/GENAI26/blob/main/Module1/LangChain_Intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **A Brief Introduction to LangChain**

# %%
# Find the latest versions of the LangChain-Google bridge and the Gemini engine, and install them
# !pip install -U -q langchain-google-genai google-genai

# %% [markdown]
# # **LangChain: An Application Chain and Not a Script**
#
# * LangChain serves as a generic interface for nearly any LLM, providing a centralized development environment to build LLM applications and integrate them with external data sources and software workflows.
#
# * LangChain’s module-based approach allows developers and data scientists to dynamically compare different prompts and even different foundation models with minimal need to rewrite code.
#
# * This modular environment also allows for programs that use multiple LLMs: for example, an application that uses one LLM to interpret user queries and another LLM to author a response.
#
# * It offers several benefits to developers including:
#
# ---
# 1.   **Portability**
#
# * If we use a direct Google API call, our code is **locked** to Google.
# * If we want to switch to OpenAI or Anthropic later, we have to rewrite all your request and response logic.
# * **Direct API approach** ==> Requires rewriting everything.
# * **LangChain approach** ==> We change one line (e.g., model = ChatGoogleGenerativeAI(...)) and the rest of the chain stays exactly the same.
# ---
# 2. **Standardized Pipes**
# * The **| operator** (LangChain Expression Language, LCEL) allows complex pipelines.
# * While the current chain is short, a real-world chain might look like this:
#   * **Retriever | Prompt | Model | Parser | Database_Upload**
#
# * In a simple LLM call, we have to manually handle the variables, extract the text, and pass it to the next function.
#
# * In **LangChain**, the data flows automatically through the **pipes** without the need to write middle-man code.
# ---
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Example 1**
#
# ---
# 1. Let's reates a reusable AI pipeline or **Chain** that acts like a **specialized travel assistant**.
# ![image.png](data:image/png;base64,...)
# ---
#
# 2. Instead of manually talking to the AI, we have a **machine** that follows these three steps every time we run it:
#
#  *  **Preparation (Prompt)**: It takes a city name (like "Tokyo") and plugs it into a pre-written instruction ("You are a travel guide..."). This ensures the AI always knows its job and stays on topic.
#
# * **Thinking (Model)**: It sends that specific instruction to the Gemini "brain."
#
# * **Cleaning (Parser)**: It takes the complex data sent back by the AI and strips away everything except the actual text of the answer.
#
# ---
# 3. This is useful because:
# * we can now run this for 50 different cities in a loop without rewriting a single line of travel advice.
# * every city guide will follow the exact same "3 places + 1 food" format because of the template.
# * if we want to change the assistant from a **Travel Guide** to a **History Teacher**, we only have to change one line of text (the template), and the whole machine updates instantly.
# ---
#
# ---

# %%
import os
from google.colab import userdata
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# 1. Load the key
os.environ["GOOGLE_API_KEY"] = userdata.get('GOOGLE_API_KEY')



# 2. Try the explicit model path
model_name = "models/gemini-2.5-flash-lite"

model = ChatGoogleGenerativeAI(
    model=model_name,
    temperature=0.7
)




# 3. Setup the Chain: The Variable Injection {city}

template = "You are a travel guide. Suggest 3 places in {city}."
prompt = ChatPromptTemplate.from_template(template)
chain = prompt | model | StrOutputParser()






# 4. Run it
try:
    response = chain.invoke({"city": "Tokyo"})
    print(f"Using {model_name}:")
    print(response)
except Exception as e:
    print(f"Failed with {model_name}. Error: {e}")
# Out:
# Using models/gemini-2.5-flash-lite:
# Konnichiwa! Welcome to Tokyo, a city where ancient traditions meet futuristic innovation. As your personal travel guide, I'm thrilled to suggest three incredible experiences that capture the diverse spirit of this vibrant metropolis. Get ready for an unforgettable journey!
#
# Here are my top 3 picks for you in Tokyo:
#
# 1.  **Immerse Yourself in Tradition and Tranquility at Senso-ji Temple and Asakusa:**
#     *   **Why visit:** Step back in time at Tokyo's oldest temple, Senso-ji, a magnificent Buddhist sanctuary that exudes a sense of peace and spirituality amidst the bustling city. The iconic Kaminarimon Gate (Thunder Gate) with its giant red lantern is an instantly recognizable landmark. Wander through Nakamise-dori, the lively market street leading to the temple, filled with traditional snacks, souvenirs, and crafts.
#     *   **What to do:**
#         *   **Explore the temple grounds:** Admire the intricate architecture, offer a prayer, and soak in the atmosphere.
#         *   **Shop for souvenirs:** Nakamise-dori is perfect for picking up unique gifts and trying local treats like *agemanju* (fried sweet buns) and *kaminari okoshi* (crispy rice crackers).
#         *   **Experience a rickshaw ride:** For a romantic or fun perspective, consider a rickshaw tour through the charming streets of Asakusa.
#         *   **Enjoy the views:** From the temple grounds, you can see the striking Tokyo Skytree in the distance, a fascinating juxtaposition of old and new.
#     *   **Best for:** History buffs, culture enthusiasts, and anyone seeking a taste of traditional Japan.
#
# 2.  **Experience the Electric Energy and Pop Culture Haven of Shibuya:**
#     *   **Why visit:** Shibuya is the beating heart of modern Tokyo's youth culture and fashion. It's most famous for the iconic **Shibuya Scramble Crossing**, the world's busiest intersection, where thousands of people cross simultaneously in a mesmerizing dance. Surrounding it are towering billboards, trendy boutiques, and an electrifying atmosphere.
#     *   **What to do:**
#         *   **Conquer the Scramble Crossing:** Walk across it yourself, then head to a vantage point (like the Starbucks overlooking it or Shibuya Sky) to witness the organized chaos from above.
#         *   **Meet Hachiko:** Pay your respects at the statue of the loyal dog Hachiko, a beloved meeting spot.
#         *   **Shop till you drop:** Explore department stores like Shibuya 109 for the latest fashion trends, or browse unique independent boutiques.
#         *   **Indulge in themed cafes and restaurants:** Shibuya is home to countless themed cafes (cat cafes, anime cafes) and a vast array of dining options.
#         *   **Visit Shibuya Sky:** For breathtaking panoramic views of the city, especially at sunset and night, this observation deck is a must.
#     *   **Best for:** Trendsetters, pop culture fans, shoppers, and those who love vibrant, energetic cityscapes.
#
# 3.  **Find Serenity and Nature at the Meiji Jingu Shrine and Yoyogi Park:**
#     *   **Why visit:** Just a stone's throw from the bustling streets of Harajuku and Shibuya lies a peaceful oasis dedicated to Emperor Meiji and Empress Shoken. Meiji Jingu Shrine is a serene Shinto shrine nestled within a vast, tranquil forest. Adjacent to it is Yoyogi Park, a popular spot for locals to relax, picnic, and enjoy various activities.
#     *   **What to do:**
#         *   **Walk through the torii gates:** Enter the shrine complex through immense wooden torii gates, marking the transition from the urban world to a sacred space.
#         *   **Explore the shrine:** Visit the main sanctuary, admire the sake barrels (donated by breweries across Japan), and write your wishes on *ema* (wooden plaques).
#         *   **Stroll through the forest:** Enjoy the peaceful walk through the dense evergreen forest, a remarkable feat of urban reforestation.
#         *   **Relax in Yoyogi Park:** On weekends, you might encounter street performers, rockabilly dancers, or simply families enjoying a day outdoors. It's a great place for a picnic or people-watching.
#     *   **Best for:** Nature lovers, those seeking a peaceful escape, spiritual seekers, and anyone wanting to experience the contrast between Tokyo's urban intensity and its natural beauty.
#
# These three spots offer a fantastic introduction to the multifaceted charm of Tokyo. I hope you enjoy your visit! If you have any other questions or want more tailored recommendations, don't hesitate to ask!

# %% [markdown]
# # **Example 2**
#
# ![image.png](data:image/png;base64,...)
#
# * Instead of getting a generic "Top 3" list that everyone else gets, the AI must now find the intersection between a location and a specific interest.
#
# * It transforms a general AI into a **niche expert.** If we input **Tokyo** and **retro video games**, it skips the traditional temples and sends us to Akihabara arcade halls.
#
# * We can now create lots of travel brochures; e.g., **Paris for Hikers,** **London for Chefs**, **NYC for Kids**, etc. by simply changing the data we feed into the invoke function, without modifying the core code again.

# %%
import os
from google.colab import userdata
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# 1. Setup
os.environ["GOOGLE_API_KEY"] = userdata.get('GOOGLE_API_KEY')
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")



# 2. Updated Template with TWO variables: {city} and {travel_style}
template = """
You are a helpful travel guide.
Suggest 3 must-visit places in {city} for someone interested in {travel_style}.
Also, suggest one famous food to try there.
Format the output as a bulleted list.
"""
prompt = ChatPromptTemplate.from_template(template)



# 3. Create the Chain
chain = prompt | model | StrOutputParser()




# 4. Run the Chain with a dictionary containing both values
response = chain.invoke({
    "city": "Tokyo",
    "travel_style": "retro video games and anime"
})

print(response)
# Out:
# Here are 3 must-visit places in Tokyo for retro video game and anime enthusiasts, along with a famous food to try:
#
# *   **Akihabara Electric Town:**
#     *   **Why visit:** This is the undisputed mecca for all things anime, manga, and gaming. You'll find countless multi-story arcades packed with retro cabinets, shops overflowing with vintage games and consoles, and stores dedicated to every anime franchise imaginable. Dive into places like Super Potato for a treasure trove of retro gaming finds, and explore the themed cafes and shops for an immersive experience.
#     *   **Famous food to try:** **Ramen** - Akihabara has a huge variety of ramen shops, from traditional tonkotsu (pork bone broth) to lighter shoyu (soy sauce) based broths. It's the perfect hearty meal to fuel your gaming and shopping adventures.
#
# *   **Nakano Broadway:**
#     *   **Why visit:** While Akihabara is more about new releases and mainstream appeal, Nakano Broadway offers a more curated and often more affordable experience for retro enthusiasts. It's a multi-level shopping complex filled with independent stores specializing in vintage toys, figurines, manga, and, crucially, a fantastic selection of retro video games. Mandarake is a major anchor here with multiple branches dedicated to different collectibles.
#     *   **Famous food to try:** **Takoyaki** - These delicious, ball-shaped snacks made of a wheat-flour-based batter and filled with diced octopus are a popular street food in Japan. You'll find vendors within Nakano Broadway selling fresh, piping hot takoyaki.
#
# *   **Shinjuku Gyoen National Garden (with a retro gaming twist):**
#     *   **Why visit:** While not directly a gaming or anime spot, Shinjuku Gyoen offers a tranquil escape from the bustling city and a chance to appreciate Japanese aesthetics. *However*, for the retro gamer and anime fan, the true draw is often the *opportunity to play retro games within a serene environment*. Many cafes in the Shinjuku area, and even some within or near the garden's vicinity, offer retro gaming consoles or have a nostalgic ambiance. It's a great place to relax after a day of intense exploring, perhaps with a portable retro console or by finding a cafe that caters to this interest.
#     *   **Famous food to try:** **Taiyaki** - This is a fish-shaped cake made from a pancake-like batter, typically filled with sweet red bean paste (anko). You can find delicious taiyaki from street vendors or in cafes around the Shinjuku area. It's a sweet treat that fits perfectly with a relaxed afternoon.
